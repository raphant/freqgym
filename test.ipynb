# %%
import datetime
import time
from datetime import timedelta
from pathlib import Path
from pprint import pprint

import mpu
import nest_asyncio
import pandas as pd
import rapidjson
from freqtrade.configuration import Configuration

from lazyft.downloader import download
from lazyft.command_parameters import HyperoptParameters
from lazyft.strategy import load_strategy
from loguru import logger

from sklearn.preprocessing import robust_scale
from stable_baselines3.common.monitor import Monitor

import wandb
from trading_environments.my_freqtrade_env import Actions, SagesFreqtradeEnv

nest_asyncio.apply()

# %%
STRATEGY = "SagesGym5"
CONFIG = "configs/config.json"
PAIR = "BTC/USDT"
TRAINING_RANGE = "20180101-20201231"
VALIDATION_RANGE = "20210101-20211231"
TEST_RANGE = "20220101-"
TIMEFRAME = "1h"
freqtrade_config = Configuration.from_files([CONFIG])
freqtrade_config["timeframe"] = TIMEFRAME
freqtrade_config["pairs"] = [PAIR]
WINDOW_SIZE = 5
REQUIRED_STARTUP_CANDLES = WINDOW_SIZE
STARTING_CAPITAL = 1000
STAKE_AMOUNT = 100
# endregion

# todo load last saved score and use it as a starting point to prevent overwriting
MODEL_NAME = ""

LOAD_PREPROCESSED_DATA = False  # useful if you have to calculate a lot of features
SAVE_PREPROCESSED_DATA = True

LEARNING_TIME_STEPS = 4000000
LOG_DIR = "./logs/"
# TENSORBOARD_LOG = "./tensorboard/"
MODEL_DIR = Path("./models/")
_preprocessed_data_file = Path(
    "preprocessed",
    f"preprocessed_data__{PAIR.replace('/', '_')}__{TRAINING_RANGE}__{WINDOW_SIZE}.pickle",
)
"""End of settings"""
INDICATOR_FILTER = ["date", "open", "close", "high", "low", "volume"]

# hmm_model = Path(MODEL_DIR, f'btc_hmm.pickle')
model_dict_path = MODEL_DIR / "models.json"
if not model_dict_path.exists():
    model_dict = {}
else:
    model_dict = rapidjson.loads(model_dict_path.read_text())
    

print('Model directory:', MODEL_DIR)
print('Model dict:', model_dict)
print('Preprocessed data file:', _preprocessed_data_file)

config = {
    "strategy": STRATEGY,
    "config": CONFIG,
    "pair": PAIR,
    "training_range": TRAINING_RANGE,
    "timeframe": TIMEFRAME,
    "window_size": WINDOW_SIZE,
    "required_startup_candles": REQUIRED_STARTUP_CANDLES,
    "learning_time_steps": LEARNING_TIME_STEPS,
    "log_dir": LOG_DIR,
    "model_dir": MODEL_DIR,
    "model_dict": model_dict,
    "preprocessed_data_file": _preprocessed_data_file,
    "load_preprocessed_data": LOAD_PREPROCESSED_DATA,
    # "policy_kwargs": POLICY_KWARGS,
    "starting_capital": STARTING_CAPITAL,
    "stake_amount": STAKE_AMOUNT,
}
print('Config:')
pprint(config)
# Out:
# Model directory: models
# Model dict: {}
# Preprocessed data file: preprocessed/preprocessed_data__BTC_USDT__20180101-20201231__5.pickle
# Config:
# {'config': 'configs/config.json',
#  'learning_time_steps': 4000000,
#  'load_preprocessed_data': False,
#  'log_dir': './logs/',
#  'model_dict': {},
#  'model_dir': PosixPath('models'),
#  'pair': 'BTC/USDT',
#  'preprocessed_data_file': PosixPath('preprocessed/preprocessed_data__BTC_USDT__20180101-20201231__5.pickle'),
#  'required_startup_candles': 5,
#  'stake_amount': 100,
#  'starting_capital': 1000,
#  'strategy': 'SagesGym5',
#  'timeframe': '1h',
#  'training_range': '20180101-20201231',
#  'window_size': 5}

# %%
from freqtrade.data import history
from freqtrade.configuration import TimeRange
from lazyft.data_loader import load_pair_data

timerange = TimeRange.parse_timerange(TRAINING_RANGE)

ohlc_data = history.load_data(
    datadir=freqtrade_config["datadir"],
    pairs=[PAIR],
    timeframe=TIMEFRAME,
    timerange=timerange,
   startup_candles=REQUIRED_STARTUP_CANDLES + 1,
    fail_without_data=True,
    data_format=freqtrade_config.get("dataformat_ohlcv", "json"),
)
price_data: pd.DataFrame = load_pair_data(PAIR,TIMEFRAME, timerange=TRAINING_RANGE, startup_candles=REQUIRED_STARTUP_CANDLES)
print('Loaded data:\n', price_data)
# Out:
# Loaded data:
# 2023-10-12 14:37:05.757 | INFO     | lazyft.data_loader:load_pair_data:47 - Loaded 11153 rows for BTC/USDT @ timeframe 1h, data starts at 2019-09-23 08:00:00+00:00
#                             date  open  high   low  close  volume
# 0     2019-09-23 08:00:00+00:00 9.93K 9.93K 9.93K  9.93K   0.001
# 1     2019-09-23 09:00:00+00:00 9.93K 9.93K 9.93K  9.93K   0.000
# 2     2019-09-23 10:00:00+00:00 9.93K 9.93K 9.93K  9.93K   0.000
# 3     2019-09-23 11:00:00+00:00 9.93K 9.93K 9.93K  9.93K   0.000
# 4     2019-09-23 12:00:00+00:00 9.93K 9.93K 9.93K  9.93K   0.000
# ...                         ...   ...   ...   ...    ...     ...
# 11148 2020-12-30 20:00:00+00:00 28.8K   29K 28.6K  28.8K  11.538
# 11149 2020-12-30 21:00:00+00:00 28.8K   29K 28.6K  28.9K  16.847
# 11150 2020-12-30 22:00:00+00:00 28.9K 28.9K 28.6K  28.7K   4.966
# 11151 2020-12-30 23:00:00+00:00 28.7K 28.9K 28.6K  28.9K  11.346
# 11152 2020-12-31 00:00:00+00:00 28.9K 29.3K 28.9K  29.1K  29.346
#
# [11153 rows x 6 columns]
# /Users/raphael/PycharmProjects/freqgym/venv/lib/python3.11/site-packages/freqtrade/data/history/jsondatahandler.py:122: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   pairdata['date'] = to_datetime(pairdata['date'],

# %%
from user_data.strategies import custom_indicators

price_data = custom_indicators.add_smi_signal(price_data)
price_data = custom_indicators.add_ema_signal(price_data)
price_data = custom_indicators.add_sar_signal(price_data)
price_data = custom_indicators.add_ha_signal(price_data)
price_data = custom_indicators.add_adx_di_signal(price_data)
price_data = custom_indicators.add_rsi_signal(price_data)
price_data = custom_indicators.add_bollinger_signal(price_data)
# price_data = custom_indicators.add_donchian_trend_signal(price_data)
# Out:
# /Users/raphael/PycharmProjects/freqgym/user_data/strategies/custom_indicators.py:243: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bollinger_signal"].iloc[i] = 1

# %%
import numpy as np

selected_data = price_data.drop(columns=["open", "close", "high", "low", "volume"])
# set to float32
selected_data_dict = {row['date']: row[1:].values for _, row in selected_data.iterrows()}
for key in selected_data_dict:
    selected_data_dict[key] = np.array(selected_data_dict[key], dtype=np.float32)


print('Selected data:\n', selected_data_dict)
from trading_environments.my_freqtrade_env4 import Actions, SagesFreqtradeEnv4
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.utils import set_random_seed
env = SagesFreqtradeEnv4(
    data=selected_data_dict,
    prices=price_data[["date", "open", "close", "high", "low", "volume"]],
    window_size=WINDOW_SIZE,  # how many past candles should it use as features
    pair=PAIR,
    stake_amount=STAKE_AMOUNT,
    starting_balance=STARTING_CAPITAL,
    punish_holding_amount=-2,
)
check_env(env)
trading_env = Monitor(env, LOG_DIR)
set_random_seed(1111, using_cuda=True)
config['action_shape'] = len(Actions)
config['punish_holding_amount'] = env.punish_holding_amount
# Out:
# Selected data:
#  {Timestamp('2019-09-23 08:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 09:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 10:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 17:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 19:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 20:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 21:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-23 22:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 0.], dtype=float32), Timestamp('2019-09-23 23:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 0.], dtype=float32), Timestamp('2019-09-24 00:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 0.], dtype=float32), Timestamp('2019-09-24 01:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 0.], dtype=float32), Timestamp('2019-09-24 02:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 0.], dtype=float32), Timestamp('2019-09-24 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 04:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 07:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 08:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 09:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 10:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 17:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 19:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 20:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-24 21:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 0.], dtype=float32), Timestamp('2019-09-24 22:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 0.], dtype=float32), Timestamp('2019-09-24 23:00:00+0000', tz='UTC'): array([1., ...
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-25 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 0.], dtype=float32), Timestamp('2019-09-25 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-25 17:00:00+0000', tz='UTC'): array([1., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-25 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-25 19:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-25 20:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0427355, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-09-25 21:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.11749016, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-25 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.11327858, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-25 23:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02301559, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-26 00:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-26 01:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-26 02:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-26 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-26 04:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-26 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-26 06:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00969078, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-26 07:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00362003, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-26 08:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00289899, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-26 09:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02729967, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-26 10:00:00+0000', tz='UTC'): array([1.        , 0.        , 0.        , 0.03685982, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-26 11:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02110485, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-26 12:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00324303, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-26 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-09-26 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-26 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-26 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-26 17:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-26 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-26 19:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-26 20:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00274013, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-26 21:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-26 22:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-26 23:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01312185, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-27 00:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 01:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 02:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 04:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 07:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02316891, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-27 08:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.04888871, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-27 09:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01975249, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-27 10:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0225537, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-09-27 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-27 17:00:00+0000', tz='UTC'): array([1.        , 0.        , 0.        , 0.00274422, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-27 18:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02102952, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-27 19:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01791454, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-27 20:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01765231, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-27 21:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.09290728, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-27 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.13117698, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-27 23:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.10265947, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 00:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.09035496, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 01:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.06292821, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 02:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0229353, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-09-28 03:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01653548, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 04:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01460181, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 05:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01043811, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 06:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00407584, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 07:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01920536, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 08:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02685886, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 09:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01954188, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 10:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02738979, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-28 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-28 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-28 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-28 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-28 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-28 17:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-28 18:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02811333, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 19:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02067629, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 20:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.04525461, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 21:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02308434, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03568435, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-28 23:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0369112, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-09-29 00:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.04188299, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-29 01:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02275852, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-29 02:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00905491, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-29 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 04:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 07:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 08:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 09:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 10:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-09-29 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-09-29 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 17:00:00+0000', tz='UTC'): array([1., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 19:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 20:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-29 21:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01660404, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-29 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.05840905, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-29 23:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.05319056, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 00:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02114719, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 01:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-30 02:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-30 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-30 04:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-30 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-30 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-09-30 07:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-30 08:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-09-30 09:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02794577, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 10:00:00+0000', tz='UTC'): array([1.        , 0.        , 0.        , 0.11149877, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 11:00:00+0000', tz='UTC'): array([0.      , 0.      , 0.      , 0.130243, 0.      , 0.      ,
#        0.      ], dtype=float32), Timestamp('2019-09-30 12:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.10200736, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 13:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.10646103, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 14:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.15091722, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 15:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.19204798, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 16:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.19019973, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 17:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.13598327, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 18:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.1097893, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-09-30 19:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.07765038, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 20:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03136534, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 21:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01274321, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01008124, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-09-30 23:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02690469, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 00:00:00+0000', tz='UTC'): array([0.    , 0.    , 0.    , 0.0137, 0.    , 0.    , 0.    ],
#       dtype=float32), Timestamp('2019-10-01 01:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00374454, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 02:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.06791289, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 03:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.13293266, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 04:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.12744561, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 05:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.10110665, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 06:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.05642492, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 07:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03208631, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 08:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01586984, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 09:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-01 10:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-01 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-01 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-01 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-01 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-01 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-01 16:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02934675, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 17:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01757755, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-01 19:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-01 20:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-01 21:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00122221, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-01 22:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-01 23:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 00:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 01:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 02:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 04:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-10-02 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-10-02 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 07:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 08:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 09:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00439975, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-02 10:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00917934, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-02 11:00:00+0000', tz='UTC'): array([1.        , 0.        , 0.        , 0.02032699, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-02 12:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01595741, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-02 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 17:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-02 18:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00011963, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-02 19:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0075592, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-02 20:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01101415, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-02 21:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00615652, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-02 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01546428, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-02 23:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.05643868, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-03 00:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.07756409, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-03 01:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.05932466, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-03 02:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.04658741, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-03 03:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03396104, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-03 04:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02850896, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-03 05:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00622053, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-03 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 07:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 08:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 09:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 10:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-10-03 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 17:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 19:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 20:00:00+0000', tz='UTC'): array([1., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 21:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-03 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01403022, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-03 23:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.04767314, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 00:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01047869, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 01:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-04 02:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-04 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-04 04:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-04 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-04 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-04 07:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00791651, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 08:00:00+0000', tz='UTC'): array([1.        , 0.        , 0.        , 0.00410981, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 09:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00206861, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 10:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0217679, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-04 11:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0274014, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-04 12:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0257105, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-04 13:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0251929, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-04 14:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02810505, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 15:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01623625, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 16:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01550368, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 17:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01696299, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 18:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01822034, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 19:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02224835, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 20:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01322799, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-04 21:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-04 22:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-04 23:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 00:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 01:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 02:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 04:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 07:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 08:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-10-05 09:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-10-05 10:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-10-05 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 16:00:00+0000', tz='UTC'): array([1., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 17:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-05 19:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00049956, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-05 20:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01037399, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-05 21:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03761745, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-05 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.05195631, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-05 23:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03839744, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-06 00:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03133054, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-06 01:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00261851, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-06 02:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 04:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-10-06 07:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-10-06 08:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 1., 1.], dtype=float32), Timestamp('2019-10-06 09:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 10:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 15:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01258368, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-06 16:00:00+0000', tz='UTC'): array([1.        , 0.        , 0.        , 0.04278735, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-06 17:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03966483, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-06 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 19:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 20:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 21:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 22:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-06 23:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-07 00:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-07 01:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-07 02:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-07 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-07 04:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00127802, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-07 06:00:00+0000', tz='UTC'): array([1., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-07 07:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00201336, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 08:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02868494, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 09:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.04251274, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 10:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.08972036, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 11:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.1048905, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-07 12:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.12333848, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 13:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.16599853, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 14:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.15147753, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 15:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.14000678, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 16:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.13201511, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 17:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.13640007, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 18:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.1159971, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-07 19:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0739456, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-07 20:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03456715, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 21:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0110009, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-07 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01142001, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-07 23:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01163088, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-08 00:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00762287, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-08 01:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02772938, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-08 02:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.04830261, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-08 03:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03518337, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-08 04:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01713417, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-08 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 07:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 08:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 09:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 10:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 13:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01343088, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-08 14:00:00+0000', tz='UTC'): array([0.000000e+00, 0.000000e+00, 0.000000e+00, 6.374716e-04,
#        1.000000e+00, 0.000000e+00, 0.000000e+00], dtype=float32), Timestamp('2019-10-08 15:00:00+0000', tz='UTC'): array([0.000000e+00, 0.000000e+00, 0.000000e+00, 9.737426e-04,
#        1.000000e+00, 0.000000e+00, 0.000000e+00], dtype=float32), Timestamp('2019-10-08 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 17:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 19:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2019-10-08 20:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-08 21:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-08 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00039945, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-08 23:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0120755, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-09 00:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00865528, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-09 01:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00415743, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-09 02:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-09 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2019-10-09 04:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-09 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-09 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2019-10-09 07:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0063097, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-09 08:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.0182608, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2019-10-09 09:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.2453535 , 0.02887546, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-09 10:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03836416, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-09 11:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02429667, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-09 12:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00458134, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-09 13:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01751973, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-09 14:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.10191023, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-09 15:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.22422008, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2019-10-09 16:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.25666982, 1.        ,
# ...
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-26 08:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.06226954, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-26 09:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.05673313, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-26 10:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2020-12-26 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2020-12-26 12:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.02287848, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-26 13:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.06940398, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-26 14:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.42361033, 0.22980797, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-26 15:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.46275616, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-26 16:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.61299694, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-26 17:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.6138888, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-26 18:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.4358327, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-26 19:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.33811805, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-26 20:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.4918185, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-26 21:00:00+0000', tz='UTC'): array([0.      , 0.      , 0.      , 0.726049, 1.      , 0.      ,
#        0.      ], dtype=float32), Timestamp('2020-12-26 22:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.6307217, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-26 23:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.4801398, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-27 00:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.45900044, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-27 01:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.4257881, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-27 02:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.28890643, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-27 03:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.14416854, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-27 04:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.14620185, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-27 05:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.21100648, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-27 06:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.4862929, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-27 07:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.71260893, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-27 08:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.6613596, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-27 09:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.51550114, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-27 10:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.5124999, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-27 11:00:00+0000', tz='UTC'): array([0.     , 0.     , 0.     , 0.37726, 1.     , 0.     , 0.     ],
#       dtype=float32), Timestamp('2020-12-27 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2020-12-27 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2020-12-27 14:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2020-12-27 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2020-12-27 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-27 17:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-27 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-27 19:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-27 20:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2020-12-27 21:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-27 22:00:00+0000', tz='UTC'): array([0., 1., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-27 23:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-28 00:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-28 01:00:00+0000', tz='UTC'): array([0.        , 1.        , 0.6143553 , 0.20152505, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-28 02:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.31044638, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-28 03:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.3530247, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-28 04:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.26552588, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-28 05:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.10971275, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-28 06:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.06796857, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-28 07:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.08917642, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-28 08:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-28 09:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-28 10:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-28 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-28 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-28 13:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.21850154, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-28 14:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.2664768, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-28 15:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.1369008, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-28 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-28 17:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.03851509, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-28 18:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.01849418, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-28 19:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-28 20:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-28 21:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2020-12-28 22:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-28 23:00:00+0000', tz='UTC'): array([0., 1., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-29 00:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.00739372, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-29 01:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-29 02:00:00+0000', tz='UTC'): array([0., 1., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-29 03:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2020-12-29 04:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 1.], dtype=float32), Timestamp('2020-12-29 05:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-29 06:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-29 07:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-29 08:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-29 09:00:00+0000', tz='UTC'): array([0.        , 1.        , 0.        , 0.07572928, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-29 10:00:00+0000', tz='UTC'): array([0.        , 1.        , 0.4047118 , 0.13926786, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-29 11:00:00+0000', tz='UTC'): array([0.        , 1.        , 0.        , 0.19220394, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-29 12:00:00+0000', tz='UTC'): array([0.        , 1.        , 0.        , 0.26338482, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-29 13:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.21106862, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-29 14:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.08244129, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-29 15:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-29 16:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-29 17:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-29 18:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-29 19:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.06773258, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-29 20:00:00+0000', tz='UTC'): array([0.        , 1.        , 0.        , 0.19603993, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-29 21:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.2509909, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-29 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.23566417, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-29 23:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.3134443, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-30 00:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.5150136, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-30 01:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.5365362, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-30 02:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.5529426, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-30 03:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.61553496, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-30 04:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.5062964, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-30 05:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.38575655, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-30 06:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.4465633, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-30 07:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.48982307, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-30 08:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.2098089, 1.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-30 09:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2020-12-30 10:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 1., 0., 0.], dtype=float32), Timestamp('2020-12-30 11:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-30 12:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-30 13:00:00+0000', tz='UTC'): array([0., 0., 0., 0., 0., 0., 0.], dtype=float32), Timestamp('2020-12-30 14:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.07572128, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-30 15:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.18413211, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-30 16:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.15948093, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-30 17:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.44960582, 0.16575678, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-30 18:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.2635634, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-30 19:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.42773968, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-30 20:00:00+0000', tz='UTC'): array([0.       , 0.       , 0.       , 0.4911253, 0.       , 0.       ,
#        0.       ], dtype=float32), Timestamp('2020-12-30 21:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.44223726, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-30 22:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.32118267, 0.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-30 23:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.23880458, 1.        ,
#        0.        , 0.        ], dtype=float32), Timestamp('2020-12-31 00:00:00+0000', tz='UTC'): array([0.        , 0.        , 0.        , 0.33516446, 1.        ,
#        0.        , 0.        ], dtype=float32)}
# 2023-10-12 14:37:09.981 | INFO     | trading_environments.my_freqtrade_env4:__init__:132 - Observation space: Box(0.0, 1.0, (7,), float32)
# 2023-10-12 14:37:09.981 | INFO     | trading_environments.my_freqtrade_env4:__init__:142 - Prices columns: ['date', 'open', 'close', 'high', 'low', 'volume'], shape: (11153, 6)

# %%
from pathlib import Path
from tb_callbacks import SaveOnStepCallback
from stable_baselines3 import DQN
from sb3_contrib.ppo_recurrent import RecurrentPPO
from sb3_contrib.qrdqn import QRDQN


# POLICY_KWARGS = dict(net_arch=[128, 128])

if MODEL_NAME:
        # load existing model
        model = RecurrentPPO.load(
            MODEL_DIR / MODEL_NAME.strip(".zip"),
            # tensorboard_log=TENSORBOARD_LOG,
        )
        logger.success(f"Loaded model from {MODEL_DIR / MODEL_NAME}")
        model.set_env(trading_env)
else:
    # policy = RecurrentActorCriticPolicy
    model = RecurrentPPO(
        # See https://stable-baselines3.readthedocs.io/en/master/guide/algos.html for other algos with discrete action space
        # "MultiInputLstmPolicy",
        "MlpLstmPolicy",
        # "MlpPolicy",
        trading_env,
        verbose=0,
        device="cuda",
        # tensorboard_log=TENSORBOARD_LOG,
        n_steps=len(price_data) - WINDOW_SIZE,
        # gradient_steps=-1,
        gamma=0.9,
        learning_rate=0.0001,
        batch_size=64,
        # ent_coef=0.0001123894292050861,
        # gae_lambda=0.8789545362092943,
        # reuse=True
        # policy_kwargs=POLICY_KWARGS,
    )
start_date = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
base_name = f"{STRATEGY}_{trading_env.env.__class__.__name__}_{model.__class__.__name__}_{start_date}"
tb_callback = SaveOnStepCallback(
    check_freq=len(price_data)*5,
    save_name=f"best_model_{base_name}",
    save_dir=str(MODEL_DIR),
    log_dir=LOG_DIR,
    verbose=1,
)
config['model_type'] = model.__class__.__name__
config['save_name'] = base_name
env.set_log_dir(Path('trade_logs', start_date))
print(base_name)
# Out:
# 2023-10-12 14:37:10.224 | INFO     | trading_environments.my_freqtrade_env4:set_log_dir:623 - Log directory set to trade_logs/20231012_143710
# SagesGym5_SagesFreqtradeEnv4_RecurrentPPO_20231012_143710

# %%
run = wandb.init(project="freqgym", entity="rtnanje", config=config)
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Appending key for api.wandb.ai to your netrc file: /Users/raphael/.netrc
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/raphael/PycharmProjects/freqgym/wandb/run-20231012_143722-a00gr4fi</code>
# Syncing run <strong><a href='https://wandb.ai/rtnanje/freqgym/runs/a00gr4fi' target="_blank">tough-capybara-94</a></strong> to <a href='https://wandb.ai/rtnanje/freqgym' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/rtnanje/freqgym' target="_blank">https://wandb.ai/rtnanje/freqgym</a>
#  View run at <a href='https://wandb.ai/rtnanje/freqgym/runs/a00gr4fi' target="_blank">https://wandb.ai/rtnanje/freqgym/runs/a00gr4fi</a>

# %%
from wandb.integration.sb3 import WandbCallback

logger.info("Learning started.")
callback = WandbCallback(
    model_save_path=f"models/best_model_{run.id}",
    verbose=2,
    model_save_freq=len(price_data) * 5,
)

# wandb.watch(model)
model.learn(total_timesteps=LEARNING_TIME_STEPS, callback=callback)
# Out:
# 2023-10-12 14:37:22.704 | INFO     | __main__:<module>:3 - Learning started.
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1020.0, 'Step/balance': 996.0, 'Step/trades': 4.0, 'Step/total_profit_pct': -3.98, 'Step/custom_score': -15.92, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.13541666666666666}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.125}
# {'Step/total_reward': -1004.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1007.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.25}
# {'Step/total_reward': -1006.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.1875}
# {'Step/total_reward': -1001.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.125}
# {'Step/total_reward': -1006.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.1875}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1007.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.05555555555555555}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.125}
# {'Step/total_reward': -1001.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.16666666666666666}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1008.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1019.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.2916666666666667}
# {'Step/total_reward': -1007.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.20833333333333334}
# {'Step/total_reward': -1015.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.18055555555555555}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1021.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.125}
# {'Step/total_reward': -1007.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.125}
# {'Step/total_reward': -1020.0, 'Step/balance': 996.0, 'Step/trades': 4.0, 'Step/total_profit_pct': -3.98, 'Step/custom_score': -15.92, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1011.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.09722222222222222}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1007.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1007.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.375}
# {'Step/total_reward': -1013.0, 'Step/balance': 995.0, 'Step/trades': 5.0, 'Step/total_profit_pct': -4.98, 'Step/custom_score': -24.88, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 5.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.10833333333333334}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1006.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.1875}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1020.92784687, 'Step/balance': 993.07215313, 'Step/trades': 4.0, 'Step/total_profit_pct': -6.89, 'Step/custom_score': -27.57, 'Step/avg_profit_pct': -1.72, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.16666666666666666}
# {'Step/total_reward': -1001.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1001.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1006.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1018.0, 'Step/balance': 996.0, 'Step/trades': 4.0, 'Step/total_profit_pct': -3.98, 'Step/custom_score': -15.92, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.14583333333333334}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1001.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1004.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.16666666666666666}
# {'Step/total_reward': -1005.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.09722222222222222}
# {'Step/total_reward': -1007.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1002.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1023.10399864, 'Step/balance': 992.89600136, 'Step/trades': 4.0, 'Step/total_profit_pct': -7.07, 'Step/custom_score': -28.27, 'Step/avg_profit_pct': -1.77, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.19791666666666666}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1008.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0625}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1013.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.1111111111111111}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1039.21262306, 'Step/balance': 992.78737694, 'Step/trades': 7.0, 'Step/total_profit_pct': -7.18, 'Step/custom_score': -50.24, 'Step/avg_profit_pct': -1.03, 'Step/winning_trades': 0.0, 'Step/losing_trades': 7.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.06547619047453704}
# {'Step/total_reward': -1004.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.10416666666666667}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.125}
# {'Step/total_reward': -1014.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.22916666666666666}
# {'Step/total_reward': -1008.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0625}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1013.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.1111111111111111}
# {'Step/total_reward': -1013.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.5833333333333334}
# {'Step/total_reward': -1009.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.20833333333333334}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1004.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1007.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1004.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1001.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1006.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1010.0, 'Step/balance': 996.0, 'Step/trades': 4.0, 'Step/total_profit_pct': -3.98, 'Step/custom_score': -15.92, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.10416666666666667}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.125}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1002.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0625}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1018.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.3333333333333333}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1001.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1006.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1033.49962383, 'Step/balance': 990.50037617, 'Step/trades': 5.0, 'Step/total_profit_pct': -9.45, 'Step/custom_score': -47.26, 'Step/avg_profit_pct': -1.89, 'Step/winning_trades': 0.0, 'Step/losing_trades': 5.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.20833333333333334}
# {'Step/total_reward': -1006.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1009.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1004.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1011.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.05555555555555555}
# {'Step/total_reward': -1014.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.20833333333333334}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1042.97956863, 'Step/balance': 977.02043137, 'Step/trades': 9.0, 'Step/total_profit_pct': -22.87, 'Step/custom_score': -205.79, 'Step/avg_profit_pct': -2.54, 'Step/winning_trades': 1.0, 'Step/losing_trades': 8.0, 'Step/win_ratio': 11.11, 'Step/average_duration (d)': 0.11574074074074074}
# {'Step/total_reward': -1013.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.2916666666666667}
# {'Step/total_reward': -1019.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.20833333333333334}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.125}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1006.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1009.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1020.0, 'Step/balance': 996.0, 'Step/trades': 4.0, 'Step/total_profit_pct': -3.98, 'Step/custom_score': -15.92, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.13541666666666666}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1007.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1029.10399864, 'Step/balance': 992.89600136, 'Step/trades': 4.0, 'Step/total_profit_pct': -7.07, 'Step/custom_score': -28.27, 'Step/avg_profit_pct': -1.77, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.19791666666666666}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1001.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1004.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.125}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1006.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1001.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.20833333333333334}
# {'Step/total_reward': -1005.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1012.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1001.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.041666666666666664}
# {'Step/total_reward': -1006.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.10416666666666667}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1005.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.06944444444444445}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.20833333333333334}
# {'Step/total_reward': -1033.10399864, 'Step/balance': 990.89600136, 'Step/trades': 6.0, 'Step/total_profit_pct': -9.06, 'Step/custom_score': -54.35, 'Step/avg_profit_pct': -1.51, 'Step/winning_trades': 0.0, 'Step/losing_trades': 6.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.09722222222222222}
# ...
# {'Step/total_reward': -1013.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.2638888888888889}
# {'Step/total_reward': -1043.27044552, 'Step/balance': 980.72955448, 'Step/trades': 8.0, 'Step/total_profit_pct': -19.17, 'Step/custom_score': -153.4, 'Step/avg_profit_pct': -2.4, 'Step/winning_trades': 2.0, 'Step/losing_trades': 6.0, 'Step/win_ratio': 25.0, 'Step/average_duration (d)': 0.2916666666666667}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.2916666666666667}
# {'Step/total_reward': -1013.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.23611111111111113}
# {'Step/total_reward': -1028.75418371, 'Step/balance': 985.24581629, 'Step/trades': 2.0, 'Step/total_profit_pct': -14.68, 'Step/custom_score': -29.36, 'Step/avg_profit_pct': -7.34, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.5625}
# {'Step/total_reward': -1018.0, 'Step/balance': 996.0, 'Step/trades': 4.0, 'Step/total_profit_pct': -3.98, 'Step/custom_score': -15.92, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.13541666666666666}
# {'Step/total_reward': -1017.40527478, 'Step/balance': 994.59472522, 'Step/trades': 4.0, 'Step/total_profit_pct': -5.38, 'Step/custom_score': -21.51, 'Step/avg_profit_pct': -1.34, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.23958333333333334}
# {'Step/total_reward': -1069.08146914, 'Step/balance': 984.9185308599999, 'Step/trades': 11.0, 'Step/total_profit_pct': -15.01, 'Step/custom_score': -165.07, 'Step/avg_profit_pct': -1.36, 'Step/winning_trades': 2.0, 'Step/losing_trades': 9.0, 'Step/win_ratio': 18.18, 'Step/average_duration (d)': 0.25378787878472225}
# {'Step/total_reward': -1060.91908358, 'Step/balance': 975.08091642, 'Step/trades': 8.0, 'Step/total_profit_pct': -24.8, 'Step/custom_score': -198.36, 'Step/avg_profit_pct': -3.1, 'Step/winning_trades': 0.0, 'Step/losing_trades': 8.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.13541666666666666}
# {'Step/total_reward': -1112.87411555, 'Step/balance': 959.1258844500001, 'Step/trades': 23.0, 'Step/total_profit_pct': -40.67, 'Step/custom_score': -935.43, 'Step/avg_profit_pct': -1.77, 'Step/winning_trades': 4.0, 'Step/losing_trades': 19.0, 'Step/win_ratio': 17.39, 'Step/average_duration (d)': 0.17210144927083335}
# {'Step/total_reward': -1048.44087077, 'Step/balance': 983.55912923, 'Step/trades': 4.0, 'Step/total_profit_pct': -16.36, 'Step/custom_score': -65.44, 'Step/avg_profit_pct': -4.09, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.20833333333333334}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1132.30880113, 'Step/balance': 951.69119887, 'Step/trades': 34.0, 'Step/total_profit_pct': -48.07, 'Step/custom_score': -1634.33, 'Step/avg_profit_pct': -1.41, 'Step/winning_trades': 0.0, 'Step/losing_trades': 34.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.14460784313657407}
# {'Step/total_reward': -1055.52632948, 'Step/balance': 976.4736705199999, 'Step/trades': 7.0, 'Step/total_profit_pct': -23.41, 'Step/custom_score': -163.86, 'Step/avg_profit_pct': -3.34, 'Step/winning_trades': 1.0, 'Step/losing_trades': 6.0, 'Step/win_ratio': 14.29, 'Step/average_duration (d)': 0.26190476190972223}
# {'Step/total_reward': -1005.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.15277777777777776}
# {'Step/total_reward': -1007.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.18055555555555555}
# {'Step/total_reward': -1055.23136193, 'Step/balance': 978.7686380699998, 'Step/trades': 8.0, 'Step/total_profit_pct': -21.13, 'Step/custom_score': -169.01, 'Step/avg_profit_pct': -2.64, 'Step/winning_trades': 0.0, 'Step/losing_trades': 8.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.17708333333333334}
# {'Step/total_reward': -1023.06281338, 'Step/balance': 992.93718662, 'Step/trades': 3.0, 'Step/total_profit_pct': -7.03, 'Step/custom_score': -21.08, 'Step/avg_profit_pct': -2.34, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.2638888888888889}
# {'Step/total_reward': -1059.0876388, 'Step/balance': 978.9123612000001, 'Step/trades': 8.0, 'Step/total_profit_pct': -20.98, 'Step/custom_score': -167.86, 'Step/avg_profit_pct': -2.62, 'Step/winning_trades': 2.0, 'Step/losing_trades': 6.0, 'Step/win_ratio': 25.0, 'Step/average_duration (d)': 0.22916666666666666}
# {'Step/total_reward': -1039.1095695, 'Step/balance': 978.8904305, 'Step/trades': 5.0, 'Step/total_profit_pct': -21.0, 'Step/custom_score': -105.02, 'Step/avg_profit_pct': -4.2, 'Step/winning_trades': 0.0, 'Step/losing_trades': 5.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.21666666666666667}
# {'Step/total_reward': -1002.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1033.32348524, 'Step/balance': 992.67651476, 'Step/trades': 4.0, 'Step/total_profit_pct': -7.29, 'Step/custom_score': -29.15, 'Step/avg_profit_pct': -1.82, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.20833333333333334}
# {'Step/total_reward': -1009.0, 'Step/balance': 997.0, 'Step/trades': 3.0, 'Step/total_profit_pct': -2.99, 'Step/custom_score': -8.96, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.125}
# {'Step/total_reward': -1036.55050646, 'Step/balance': 981.44949354, 'Step/trades': 6.0, 'Step/total_profit_pct': -18.46, 'Step/custom_score': -110.75, 'Step/avg_profit_pct': -3.08, 'Step/winning_trades': 0.0, 'Step/losing_trades': 6.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.18055555555555555}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1023.13512941, 'Step/balance': 992.86487059, 'Step/trades': 4.0, 'Step/total_profit_pct': -7.1, 'Step/custom_score': -28.4, 'Step/avg_profit_pct': -1.77, 'Step/winning_trades': 0.0, 'Step/losing_trades': 4.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.22916666666666666}
# {'Step/total_reward': -1003.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1018.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.2916666666666667}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1047.71434734, 'Step/balance': 976.28565266, 'Step/trades': 7.0, 'Step/total_profit_pct': -23.6, 'Step/custom_score': -165.17, 'Step/avg_profit_pct': -3.37, 'Step/winning_trades': 0.0, 'Step/losing_trades': 7.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.20833333333333334}
# {'Step/total_reward': -1017.84754817, 'Step/balance': 992.15245183, 'Step/trades': 3.0, 'Step/total_profit_pct': -7.81, 'Step/custom_score': -23.43, 'Step/avg_profit_pct': -2.6, 'Step/winning_trades': 0.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.3888888888888889}
# {'Step/total_reward': -1038.80528943, 'Step/balance': 985.1947105700001, 'Step/trades': 2.0, 'Step/total_profit_pct': -14.73, 'Step/custom_score': -29.46, 'Step/avg_profit_pct': -7.37, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.625}
# {'Step/total_reward': -1001.0, 'Step/balance': 999.0, 'Step/trades': 1.0, 'Step/total_profit_pct': -1.0, 'Step/custom_score': -1.0, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 1.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.08333333333333333}
# {'Step/total_reward': -1016.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.14583333333333334}
# {'Step/total_reward': -1000.0, 'Step/balance': 1000.0, 'Step/trades': 0.0, 'Step/total_profit_pct': 0.0, 'Step/custom_score': 0.0, 'Step/avg_profit_pct': 0.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 0.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.0}
# {'Step/total_reward': -1026.09267301, 'Step/balance': 993.90732699, 'Step/trades': 2.0, 'Step/total_profit_pct': -6.06, 'Step/custom_score': -12.12, 'Step/avg_profit_pct': -3.03, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.4791666666666667}
# {'Step/total_reward': -1016.0, 'Step/balance': 998.0, 'Step/trades': 2.0, 'Step/total_profit_pct': -1.99, 'Step/custom_score': -3.98, 'Step/avg_profit_pct': -1.0, 'Step/winning_trades': 0.0, 'Step/losing_trades': 2.0, 'Step/win_ratio': 0.0, 'Step/average_duration (d)': 0.1875}
# {'Step/total_reward': -1045.74360286, 'Step/balance': 982.2563971400001, 'Step/trades': 4.0, 'Step/total_profit_pct': -17.66, 'Step/custom_score': -70.62, 'Step/avg_profit_pct': -4.41, 'Step/winning_trades': 1.0, 'Step/losing_trades': 3.0, 'Step/win_ratio': 25.0, 'Step/average_duration (d)': 0.375}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 11
#       4 callback = WandbCallback(
#       5     model_save_path=f"models/best_model_{run.id}",
#       6     verbose=2,
#       7     model_save_freq=len(price_data) * 5,
#       8 )
#      10 # wandb.watch(model)
# ---> 11 model.learn(total_timesteps=LEARNING_TIME_STEPS, callback=callback)
#
# File ~/PycharmProjects/freqgym/venv/lib/python3.11/site-packages/sb3_contrib/ppo_recurrent/ppo_recurrent.py:490, in RecurrentPPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     487         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     488         self.logger.dump(step=self.num_timesteps)
# --> 490     self.train()
#     492 callback.on_training_end()
#     494 return self
#
# File ~/PycharmProjects/freqgym/venv/lib/python3.11/site-packages/sb3_contrib/ppo_recurrent/ppo_recurrent.py:351, in RecurrentPPO.train(self)
#     348 if self.use_sde:
#     349     self.policy.reset_noise(self.batch_size)
# --> 351 values, log_prob, entropy = self.policy.evaluate_actions(
#     352     rollout_data.observations,
#     353     actions,
#     354     rollout_data.lstm_states,
#     355     rollout_data.episode_starts,
#     356 )
#     358 values = values.flatten()
#     359 # Normalize advantage
#
# File ~/PycharmProjects/freqgym/venv/lib/python3.11/site-packages/sb3_contrib/common/recurrent/policies.py:333, in RecurrentActorCriticPolicy.evaluate_actions(self, obs, actions, lstm_states, episode_starts)
#     331 latent_pi, _ = self._process_sequence(pi_features, lstm_states.pi, episode_starts, self.lstm_actor)
#     332 if self.lstm_critic is not None:
# --> 333     latent_vf, _ = self._process_sequence(vf_features, lstm_states.vf, episode_starts, self.lstm_critic)
#     334 elif self.shared_lstm:
#     335     latent_vf = latent_pi.detach()
#
# File ~/PycharmProjects/freqgym/venv/lib/python3.11/site-packages/sb3_contrib/common/recurrent/policies.py:199, in RecurrentActorCriticPolicy._process_sequence(features, lstm_states, episode_starts, lstm)
#     197 # Iterate over the sequence
#     198 for features, episode_start in zip_strict(features_sequence, episode_starts):
# --> 199     hidden, lstm_states = lstm(
#     200         features.unsqueeze(dim=0),
#     201         (
#     202             # Reset the states at the beginning of a new episode
#     203             (1.0 - episode_start).view(1, n_seq, 1) * lstm_states[0],
#     204             (1.0 - episode_start).view(1, n_seq, 1) * lstm_states[1],
#     205         ),
#     206     )
#     207     lstm_output += [hidden]
#     208 # Sequence to batch
#     209 # (sequence length, n_seq, lstm_out_dim) -> (batch_size, lstm_out_dim)
#
# File ~/PycharmProjects/freqgym/venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/PycharmProjects/freqgym/venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/PycharmProjects/freqgym/venv/lib/python3.11/site-packages/torch/nn/modules/rnn.py:879, in LSTM.forward(self, input, hx)
#     876         hx = self.permute_hidden(hx, sorted_indices)
#     878 if batch_sizes is None:
# --> 879     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     880                       self.dropout, self.training, self.bidirectional, self.batch_first)
#     881 else:
#     882     result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     883                       self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:
